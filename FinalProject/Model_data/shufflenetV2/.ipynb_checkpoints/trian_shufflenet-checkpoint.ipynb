# %%
import os
import shutil
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import torch.optim as optim

# 資料增強與標準化
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# 加載數據
train_dataset = datasets.ImageFolder(root='../dataloader_c23/train', transform=transform)
val_dataset = datasets.ImageFolder(root='../dataloader_c23/validation', transform=transform)
test_dataset = datasets.ImageFolder(root='../dataloader_c23/test', transform=transform)

train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False, num_workers=2)

# %%
import tqdm as notebook_tqdm
from shufflenetV2 import shufflenet_v2_x1_5

# 設定設備
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("using {} device.".format(device))

# 加載預訓練的 MobileNetV3 大模型
model = shufflenet_v2_x1_5(num_classes = 2)
checkpoint = torch.load('shufflenetv2_x1_5-3c479a10.pth', map_location=device)

# 刪除分類層權重
pre_dict = {k: v for k, v in checkpoint.items() if k in model.state_dict() and model.state_dict()[k].numel() == v.numel()}
missing_keys, unexpected_keys = model.load_state_dict(pre_dict, strict=False)

model = model.to(device)

# 定義損失函數和優化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# using cuda device.

# %%
# 訓練函數
def train(epoch, epochs, model, train_loader, optimizer, loss_function, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    train_bar = tqdm(train_loader, file=sys.stdout)
    
    for step, data in enumerate(train_bar):
        images, labels = data
        images, labels = images.to(device), labels.to(device)  # 確保數據在正確的設備上
        optimizer.zero_grad()
        logits = model(images)  # 模型輸出
        loss = loss_function(logits, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # 計算準確率
        _, predicted = torch.max(logits, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        train_bar.desc = "train epoch[{}/{}] loss:{:.3f}".format(epoch + 1, epochs, loss)
    running_loss = running_loss / len(train_loader)
    accuracy = 100. * correct / total
    return running_loss, accuracy

# %%
# 驗證函數
def validate(epoch, epochs, model, validate_loader, loss_function, device):
    model.eval()
    acc = 0.0
    val_loss = 0.0
    val_num = len(validate_loader.dataset)
    
    with torch.no_grad():
        val_bar = tqdm(validate_loader, file=sys.stdout)
        for val_data in val_bar:
            val_images, val_labels = val_data
            val_images, val_labels = val_images.to(device), val_labels.to(device)
            outputs = model(val_images)
            loss = loss_function(outputs, val_labels)
            val_loss += loss.item() * val_images.size(0)

            predict_y = torch.max(outputs, dim=1)[1]
            acc += torch.eq(predict_y, val_labels).sum().item()

            val_bar.desc = "valid epoch[{}/{}]".format(epoch + 1, epochs)
    
    val_loss /= val_num
    val_accurate = acc / val_num
    return val_loss, val_accurate

# %%
import time
import sys
from tqdm import tqdm
# 訓練和驗證模型
num_epochs = 50
best_acc = 0.0
train_steps = len(train_loader)
save_path = 'best_shufflenetV2_1_5.pth'
t_l, t_a = [], []
v_l, v_a = [], []
for epoch in range(num_epochs):
    start_time = time.time()
    train_loss, train_accuracy = train(epoch, num_epochs, model, train_loader, optimizer, criterion, device)
    val_loss, val_accurate = validate(epoch, num_epochs, model, val_loader, criterion, device)
    t_l.append(train_loss)
    t_a.append(train_accuracy)
    v_l.append(val_loss)
    v_a.append(val_accurate)
    
    print('[epoch %d] train_loss: %.3f  train_accuracy: %.3f' %
            (epoch + 1, train_loss, train_accuracy))
    print('[epoch %d] val_loss: %.3f  val_accuracy: %.3f' %
            (epoch + 1, val_loss, val_accurate))
    
    if val_accurate > best_acc:
        best_acc = val_accurate
        torch.save(model.state_dict(), save_path)
    end_time = time.time()
    print(f'Training_Time: {end_time - start_time:.2f} seconds')
    
print('訓練完成')
# Out:
# train epoch[1/50] loss:0.180: 100%|██████████| 282/282 [01:22<00:00,  3.41it/s]
# valid epoch[1/50]: 100%|██████████| 55/55 [00:24<00:00,  2.29it/s]
# [epoch 1] train_loss: 0.001  train_accuracy: 87.096
# [epoch 1] val_loss: 0.350  val_accuracy: 0.846
# Training_Time: 106.79 seconds
# train epoch[2/50] loss:0.313: 100%|██████████| 282/282 [01:16<00:00,  3.69it/s]
# valid epoch[2/50]: 100%|██████████| 55/55 [00:21<00:00,  2.54it/s]
# [epoch 2] train_loss: 0.001  train_accuracy: 94.865
# [epoch 2] val_loss: 0.640  val_accuracy: 0.824
# Training_Time: 97.99 seconds
# train epoch[3/50] loss:0.122: 100%|██████████| 282/282 [01:20<00:00,  3.50it/s]
# valid epoch[3/50]: 100%|██████████| 55/55 [00:21<00:00,  2.57it/s]
# [epoch 3] train_loss: 0.000  train_accuracy: 96.669
# [epoch 3] val_loss: 0.440  val_accuracy: 0.861
# Training_Time: 101.96 seconds
# train epoch[4/50] loss:0.017: 100%|██████████| 282/282 [01:18<00:00,  3.59it/s]
# valid epoch[4/50]: 100%|██████████| 55/55 [00:21<00:00,  2.52it/s]
# [epoch 4] train_loss: 0.000  train_accuracy: 97.468
# [epoch 4] val_loss: 0.550  val_accuracy: 0.863
# Training_Time: 100.46 seconds
# train epoch[5/50] loss:0.143: 100%|██████████| 282/282 [01:19<00:00,  3.55it/s]
# valid epoch[5/50]: 100%|██████████| 55/55 [00:21<00:00,  2.59it/s]
# [epoch 5] train_loss: 0.000  train_accuracy: 98.028
# [epoch 5] val_loss: 0.557  val_accuracy: 0.865
# Training_Time: 100.67 seconds
# train epoch[6/50] loss:0.021: 100%|██████████| 282/282 [01:16<00:00,  3.68it/s]
# valid epoch[6/50]: 100%|██████████| 55/55 [00:20<00:00,  2.64it/s]
# [epoch 6] train_loss: 0.000  train_accuracy: 98.126
# [epoch 6] val_loss: 0.485  val_accuracy: 0.878
# Training_Time: 97.42 seconds
# train epoch[7/50] loss:0.054: 100%|██████████| 282/282 [01:19<00:00,  3.56it/s]
# valid epoch[7/50]: 100%|██████████| 55/55 [00:20<00:00,  2.62it/s]
# [epoch 7] train_loss: 0.000  train_accuracy: 98.510
# [epoch 7] val_loss: 0.965  val_accuracy: 0.825
# Training_Time: 100.17 seconds
# train epoch[8/50] loss:0.028: 100%|██████████| 282/282 [01:15<00:00,  3.72it/s]
# valid epoch[8/50]: 100%|██████████| 55/55 [00:21<00:00,  2.62it/s]
# [epoch 8] train_loss: 0.000  train_accuracy: 98.490
# [epoch 8] val_loss: 0.765  val_accuracy: 0.835
# Training_Time: 96.84 seconds
# train epoch[9/50] loss:0.033: 100%|██████████| 282/282 [01:18<00:00,  3.60it/s]
# valid epoch[9/50]: 100%|██████████| 55/55 [00:23<00:00,  2.31it/s]
# [epoch 9] train_loss: 0.000  train_accuracy: 98.747
# [epoch 9] val_loss: 0.538  val_accuracy: 0.881
# Training_Time: 102.14 seconds
# train epoch[10/50] loss:0.054: 100%|██████████| 282/282 [01:20<00:00,  3.51it/s]
# valid epoch[10/50]: 100%|██████████| 55/55 [00:19<00:00,  2.75it/s]
# [epoch 10] train_loss: 0.000  train_accuracy: 98.986
# [epoch 10] val_loss: 0.631  val_accuracy: 0.878
# Training_Time: 100.32 seconds
# train epoch[11/50] loss:0.074: 100%|██████████| 282/282 [01:17<00:00,  3.66it/s]
# valid epoch[11/50]: 100%|██████████| 55/55 [00:20<00:00,  2.73it/s]
# [epoch 11] train_loss: 0.000  train_accuracy: 98.854
# [epoch 11] val_loss: 0.737  val_accuracy: 0.833
# Training_Time: 97.19 seconds
# train epoch[12/50] loss:0.013: 100%|██████████| 282/282 [01:15<00:00,  3.72it/s]
# valid epoch[12/50]: 100%|██████████| 55/55 [00:20<00:00,  2.70it/s]
# [epoch 12] train_loss: 0.000  train_accuracy: 99.060
# [epoch 12] val_loss: 0.549  val_accuracy: 0.885
# Training_Time: 96.31 seconds
# train epoch[13/50] loss:0.077: 100%|██████████| 282/282 [01:15<00:00,  3.73it/s]
# valid epoch[13/50]: 100%|██████████| 55/55 [00:20<00:00,  2.72it/s]
# [epoch 13] train_loss: 0.000  train_accuracy: 99.014
# [epoch 13] val_loss: 0.595  val_accuracy: 0.881
# Training_Time: 95.83 seconds
# train epoch[14/50] loss:0.076: 100%|██████████| 282/282 [01:16<00:00,  3.71it/s]
# valid epoch[14/50]: 100%|██████████| 55/55 [00:20<00:00,  2.69it/s]
# [epoch 14] train_loss: 0.000  train_accuracy: 98.993
# [epoch 14] val_loss: 0.711  val_accuracy: 0.863
# Training_Time: 96.51 seconds
# train epoch[15/50] loss:0.007: 100%|██████████| 282/282 [01:17<00:00,  3.66it/s]
# valid epoch[15/50]: 100%|██████████| 55/55 [00:20<00:00,  2.65it/s]
# [epoch 15] train_loss: 0.000  train_accuracy: 99.132
# [epoch 15] val_loss: 0.600  val_accuracy: 0.875
# Training_Time: 97.89 seconds
# train epoch[16/50] loss:0.067: 100%|██████████| 282/282 [01:15<00:00,  3.72it/s]
# valid epoch[16/50]: 100%|██████████| 55/55 [00:20<00:00,  2.70it/s]
# [epoch 16] train_loss: 0.000  train_accuracy: 99.226
# [epoch 16] val_loss: 0.732  val_accuracy: 0.860
# Training_Time: 96.14 seconds
# train epoch[17/50] loss:0.039: 100%|██████████| 282/282 [01:15<00:00,  3.72it/s]
# valid epoch[17/50]: 100%|██████████| 55/55 [00:20<00:00,  2.75it/s]
# [epoch 17] train_loss: 0.000  train_accuracy: 99.114
# [epoch 17] val_loss: 0.577  val_accuracy: 0.877
# Training_Time: 95.74 seconds
# train epoch[18/50] loss:0.031: 100%|██████████| 282/282 [01:14<00:00,  3.78it/s]
# valid epoch[18/50]: 100%|██████████| 55/55 [00:20<00:00,  2.75it/s]
# [epoch 18] train_loss: 0.000  train_accuracy: 99.260
# [epoch 18] val_loss: 0.612  val_accuracy: 0.884
# Training_Time: 94.64 seconds
# train epoch[19/50] loss:0.014: 100%|██████████| 282/282 [01:15<00:00,  3.75it/s]
# valid epoch[19/50]: 100%|██████████| 55/55 [00:20<00:00,  2.72it/s]
# [epoch 19] train_loss: 0.000  train_accuracy: 99.161
# [epoch 19] val_loss: 0.675  val_accuracy: 0.875
# Training_Time: 95.47 seconds
# train epoch[20/50] loss:0.043: 100%|██████████| 282/282 [01:14<00:00,  3.79it/s]
# valid epoch[20/50]: 100%|██████████| 55/55 [00:20<00:00,  2.70it/s]
# [epoch 20] train_loss: 0.000  train_accuracy: 99.354
# [epoch 20] val_loss: 0.770  val_accuracy: 0.861
# Training_Time: 94.82 seconds
# train epoch[21/50] loss:0.065: 100%|██████████| 282/282 [01:14<00:00,  3.79it/s]
# valid epoch[21/50]: 100%|██████████| 55/55 [00:20<00:00,  2.70it/s]
# [epoch 21] train_loss: 0.000  train_accuracy: 99.272
# [epoch 21] val_loss: 0.611  val_accuracy: 0.880
# Training_Time: 94.81 seconds
# train epoch[22/50] loss:0.001: 100%|██████████| 282/282 [01:15<00:00,  3.76it/s]
# valid epoch[22/50]: 100%|██████████| 55/55 [00:20<00:00,  2.70it/s]
# [epoch 22] train_loss: 0.000  train_accuracy: 99.196
# [epoch 22] val_loss: 0.656  val_accuracy: 0.880
# Training_Time: 95.46 seconds
# train epoch[23/50] loss:0.020: 100%|██████████| 282/282 [01:15<00:00,  3.75it/s]
# valid epoch[23/50]: 100%|██████████| 55/55 [00:20<00:00,  2.72it/s]
# [epoch 23] train_loss: 0.000  train_accuracy: 99.401
# [epoch 23] val_loss: 0.629  val_accuracy: 0.876
# Training_Time: 95.44 seconds
# train epoch[24/50] loss:0.009: 100%|██████████| 282/282 [01:15<00:00,  3.75it/s]
# valid epoch[24/50]: 100%|██████████| 55/55 [00:20<00:00,  2.75it/s]
# [epoch 24] train_loss: 0.000  train_accuracy: 99.365
# [epoch 24] val_loss: 0.879  val_accuracy: 0.842
# Training_Time: 95.21 seconds
# train epoch[25/50] loss:0.006: 100%|██████████| 282/282 [01:14<00:00,  3.76it/s]
# valid epoch[25/50]: 100%|██████████| 55/55 [00:19<00:00,  2.76it/s]
# [epoch 25] train_loss: 0.000  train_accuracy: 99.382
# [epoch 25] val_loss: 0.633  val_accuracy: 0.885
# Training_Time: 94.89 seconds
# train epoch[26/50] loss:0.039: 100%|██████████| 282/282 [01:14<00:00,  3.78it/s]
# valid epoch[26/50]: 100%|██████████| 55/55 [00:20<00:00,  2.71it/s]
# [epoch 26] train_loss: 0.000  train_accuracy: 99.518
# [epoch 26] val_loss: 0.602  val_accuracy: 0.874
# Training_Time: 95.02 seconds
# train epoch[27/50] loss:0.008: 100%|██████████| 282/282 [01:15<00:00,  3.75it/s]
# valid epoch[27/50]: 100%|██████████| 55/55 [00:20<00:00,  2.72it/s]
# [epoch 27] train_loss: 0.000  train_accuracy: 99.381
# [epoch 27] val_loss: 0.806  val_accuracy: 0.825
# Training_Time: 95.57 seconds
# train epoch[28/50] loss:0.104: 100%|██████████| 282/282 [01:14<00:00,  3.77it/s]
# valid epoch[28/50]: 100%|██████████| 55/55 [00:20<00:00,  2.73it/s]
# [epoch 28] train_loss: 0.000  train_accuracy: 99.471
# [epoch 28] val_loss: 0.703  val_accuracy: 0.865
# Training_Time: 94.94 seconds
# train epoch[29/50] loss:0.084: 100%|██████████| 282/282 [01:14<00:00,  3.80it/s]
# valid epoch[29/50]: 100%|██████████| 55/55 [00:20<00:00,  2.72it/s]
# [epoch 29] train_loss: 0.000  train_accuracy: 99.460
# [epoch 29] val_loss: 0.867  val_accuracy: 0.862
# Training_Time: 94.43 seconds
# train epoch[30/50] loss:0.033: 100%|██████████| 282/282 [01:15<00:00,  3.73it/s]
# valid epoch[30/50]: 100%|██████████| 55/55 [00:20<00:00,  2.71it/s]
# [epoch 30] train_loss: 0.000  train_accuracy: 99.414
# [epoch 30] val_loss: 0.677  val_accuracy: 0.872
# Training_Time: 96.03 seconds
# train epoch[31/50] loss:0.108: 100%|██████████| 282/282 [01:16<00:00,  3.67it/s]
# valid epoch[31/50]: 100%|██████████| 55/55 [00:20<00:00,  2.73it/s]
# [epoch 31] train_loss: 0.000  train_accuracy: 99.425
# [epoch 31] val_loss: 0.662  val_accuracy: 0.875
# Training_Time: 96.97 seconds
# train epoch[32/50] loss:0.015: 100%|██████████| 282/282 [01:15<00:00,  3.71it/s]
# valid epoch[32/50]: 100%|██████████| 55/55 [00:20<00:00,  2.72it/s]
# [epoch 32] train_loss: 0.000  train_accuracy: 99.460
# [epoch 32] val_loss: 0.656  val_accuracy: 0.880
# Training_Time: 96.13 seconds
# train epoch[33/50] loss:0.002: 100%|██████████| 282/282 [01:15<00:00,  3.72it/s]
# valid epoch[33/50]: 100%|██████████| 55/55 [00:20<00:00,  2.68it/s]
# [epoch 33] train_loss: 0.000  train_accuracy: 99.517
# [epoch 33] val_loss: 0.564  val_accuracy: 0.881
# Training_Time: 96.41 seconds
# train epoch[34/50] loss:0.002: 100%|██████████| 282/282 [01:19<00:00,  3.55it/s]
# valid epoch[34/50]: 100%|██████████| 55/55 [00:21<00:00,  2.51it/s]
# [epoch 34] train_loss: 0.000  train_accuracy: 99.617
# [epoch 34] val_loss: 0.740  val_accuracy: 0.882
# Training_Time: 101.32 seconds
# train epoch[35/50] loss:0.022: 100%|██████████| 282/282 [01:18<00:00,  3.60it/s]
# valid epoch[35/50]: 100%|██████████| 55/55 [00:22<00:00,  2.41it/s]
# [epoch 35] train_loss: 0.000  train_accuracy: 99.436
# [epoch 35] val_loss: 0.639  val_accuracy: 0.884
# Training_Time: 101.26 seconds
# train epoch[36/50] loss:0.035: 100%|██████████| 282/282 [01:17<00:00,  3.66it/s]
# valid epoch[36/50]: 100%|██████████| 55/55 [00:21<00:00,  2.61it/s]
# [epoch 36] train_loss: 0.000  train_accuracy: 99.494
# [epoch 36] val_loss: 0.703  val_accuracy: 0.875
# Training_Time: 98.24 seconds
# train epoch[37/50] loss:0.028: 100%|██████████| 282/282 [01:19<00:00,  3.55it/s]
# valid epoch[37/50]: 100%|██████████| 55/55 [00:20<00:00,  2.70it/s]
# [epoch 37] train_loss: 0.000  train_accuracy: 99.500
# [epoch 37] val_loss: 0.600  val_accuracy: 0.889
# Training_Time: 99.99 seconds
# train epoch[38/50] loss:0.022: 100%|██████████| 282/282 [01:21<00:00,  3.46it/s]
# valid epoch[38/50]: 100%|██████████| 55/55 [00:20<00:00,  2.70it/s]
# [epoch 38] train_loss: 0.000  train_accuracy: 99.569
# [epoch 38] val_loss: 0.640  val_accuracy: 0.874
# Training_Time: 101.97 seconds
# train epoch[39/50] loss:0.043: 100%|██████████| 282/282 [01:19<00:00,  3.56it/s]
# valid epoch[39/50]: 100%|██████████| 55/55 [00:20<00:00,  2.65it/s]
# [epoch 39] train_loss: 0.000  train_accuracy: 99.558
# [epoch 39] val_loss: 1.203  val_accuracy: 0.823
# Training_Time: 99.90 seconds
# train epoch[40/50] loss:0.022: 100%|██████████| 282/282 [01:16<00:00,  3.68it/s]
# valid epoch[40/50]: 100%|██████████| 55/55 [00:20<00:00,  2.65it/s]
# [epoch 40] train_loss: 0.000  train_accuracy: 99.611
# [epoch 40] val_loss: 0.646  val_accuracy: 0.889
# Training_Time: 97.34 seconds
# train epoch[41/50] loss:0.002: 100%|██████████| 282/282 [01:22<00:00,  3.41it/s]
# valid epoch[41/50]: 100%|██████████| 55/55 [00:21<00:00,  2.60it/s]
# [epoch 41] train_loss: 0.000  train_accuracy: 99.565
# [epoch 41] val_loss: 0.998  val_accuracy: 0.852
# Training_Time: 103.89 seconds
# train epoch[42/50] loss:0.000: 100%|██████████| 282/282 [01:16<00:00,  3.69it/s]
# valid epoch[42/50]: 100%|██████████| 55/55 [00:20<00:00,  2.65it/s]
# [epoch 42] train_loss: 0.000  train_accuracy: 99.658
# [epoch 42] val_loss: 0.824  val_accuracy: 0.866
# Training_Time: 97.30 seconds
# train epoch[43/50] loss:0.013: 100%|██████████| 282/282 [01:16<00:00,  3.70it/s]
# valid epoch[43/50]: 100%|██████████| 55/55 [00:22<00:00,  2.46it/s]
# [epoch 43] train_loss: 0.000  train_accuracy: 99.596
# [epoch 43] val_loss: 0.810  val_accuracy: 0.870
# Training_Time: 98.67 seconds
# train epoch[44/50] loss:0.057: 100%|██████████| 282/282 [01:20<00:00,  3.51it/s]
# valid epoch[44/50]: 100%|██████████| 55/55 [00:21<00:00,  2.59it/s]
# [epoch 44] train_loss: 0.000  train_accuracy: 99.606
# [epoch 44] val_loss: 0.697  val_accuracy: 0.876
# Training_Time: 101.53 seconds
# train epoch[45/50] loss:0.023: 100%|██████████| 282/282 [01:15<00:00,  3.73it/s]
# valid epoch[45/50]: 100%|██████████| 55/55 [00:21<00:00,  2.58it/s]
# [epoch 45] train_loss: 0.000  train_accuracy: 99.593
# [epoch 45] val_loss: 0.840  val_accuracy: 0.868
# Training_Time: 96.92 seconds
# train epoch[46/50] loss:0.007: 100%|██████████| 282/282 [01:19<00:00,  3.53it/s]
# valid epoch[46/50]: 100%|██████████| 55/55 [00:21<00:00,  2.55it/s]
# [epoch 46] train_loss: 0.000  train_accuracy: 99.617
# [epoch 46] val_loss: 0.767  val_accuracy: 0.871
# Training_Time: 101.50 seconds
# train epoch[47/50] loss:0.038: 100%|██████████| 282/282 [01:23<00:00,  3.37it/s]
# valid epoch[47/50]: 100%|██████████| 55/55 [00:20<00:00,  2.72it/s]
# [epoch 47] train_loss: 0.000  train_accuracy: 99.624
# [epoch 47] val_loss: 0.734  val_accuracy: 0.875
# Training_Time: 103.98 seconds
# train epoch[48/50] loss:0.031: 100%|██████████| 282/282 [01:16<00:00,  3.71it/s]
# valid epoch[48/50]: 100%|██████████| 55/55 [00:20<00:00,  2.72it/s]
# [epoch 48] train_loss: 0.000  train_accuracy: 99.618
# [epoch 48] val_loss: 0.662  val_accuracy: 0.879
# Training_Time: 96.26 seconds
# train epoch[49/50] loss:0.004: 100%|██████████| 282/282 [01:18<00:00,  3.59it/s]
# valid epoch[49/50]: 100%|██████████| 55/55 [00:20<00:00,  2.66it/s]
# [epoch 49] train_loss: 0.000  train_accuracy: 99.658
# [epoch 49] val_loss: 0.764  val_accuracy: 0.883
# Training_Time: 99.22 seconds
# train epoch[50/50] loss:0.048: 100%|██████████| 282/282 [01:18<00:00,  3.57it/s]
# valid epoch[50/50]: 100%|██████████| 55/55 [00:22<00:00,  2.50it/s]
# [epoch 50] train_loss: 0.000  train_accuracy: 99.744
# [epoch 50] val_loss: 1.004  val_accuracy: 0.859
# Training_Time: 100.95 seconds
# 訓練完成

# %%
# 測試模型
model.load_state_dict(torch.load('best_shufflenetV2_1_5.pth'))
model.eval()
test_running_corrects = 0

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        test_running_corrects += torch.sum(preds == labels.data)

test_acc = test_running_corrects.double() / len(test_dataset)
print(f'Test Acc: {test_acc:.4f}')
# Out:
# Test Acc: 0.9026

# %%
def save_metrics_to_file(t_l, t_a, v_l, v_a, filename='metrics.txt'):
    with open(filename, 'w') as file:
        file.write("Train Loss:\n")
        for item in t_l:
            file.write(f"{item}\n")
        
        file.write("Train Accuracy:\n")
        for item in t_a:
            file.write(f"{item}\n")
        
        file.write("Validation Loss:\n")
        for item in v_l:
            file.write(f"{item}\n")
        
        file.write("Validation Accuracy:\n")
        for item in v_a:
            file.write(f"{item}\n")

# %%
# 假設 t_l, t_a, v_l, v_a 已經被填充
filename = 'shufflenetV2.txt'
save_metrics_to_file(t_l, t_a, v_l, v_a, filename)

# %%
test_celeb_dataset = datasets.ImageFolder(root='../archive/extracted_frames', transform=transform)
celeb_loader = DataLoader(test_celeb_dataset, batch_size=256, shuffle=False, num_workers=2)

# 測試模型
model.load_state_dict(torch.load('best_shufflenetV2_1_5.pth'))
model.eval()
test_running_corrects = 0

with torch.no_grad():
    for inputs, labels in celeb_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        test_running_corrects += torch.sum(preds == labels.data)

test_acc = test_running_corrects.double() / len(test_dataset)
print(f'Test Acc of Celeb DF V2: {test_acc:.4f}')
# Out:
# Test Acc of Celeb DF V2: 0.7308

# %%
# 使用 TorchScript 將模型保存為 .pt 文件
import torch

# 加載預訓練的 MobileNetV3 大模型
model = shufflenet_v2_x1_5(num_classes = 2)
model.load_state_dict(torch.load('best_shufflenetV2_1_5.pth'))
model.eval()

example_input = torch.rand(1, 3, 224, 224)
traced_script_module = torch.jit.trace(model, example_input)
torch.jit.save(traced_script_module, 'shufflenetV2_jit.pt')
